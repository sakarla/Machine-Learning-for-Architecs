# %% [markdown]
# <a href="https://colab.research.google.com/github/sakarla/AI-in-the-Built-Environment/blob/main/week%204_5_Data%20Visualization/Notebook%20code/data_preprocessing_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Image analysis and preprocessing**
# In this section, we will implement several preprocessing techniques on the image data. The objective is to familiarize you with essential steps that enhance data clarity, ensuring it is well-prepared for the machine learning process.
# * Read URLs from json or csv file and show image
# * Learn image preprocessing:
#
#   *  Resizing
#   * Grayscale conversion
#   * Normalization
#   * Flattening
# *  Edge detection
# *  Save feature extracted from images into csv file
#
# Let's get started!

# %% [markdown]
# # **Read URLs from json or csv file and show image**

# %% [markdown]
# To start, we will link this notebook to your Google Drive. Make sure you are logged in on your Google account

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import os

# Specify the folder containing your JSON files
folder_path = '/content/drive/MyDrive/ai class data/image'

# List all JSON files in the folder
json_files = [file for file in os.listdir(folder_path) if file.endswith('.json')]

combined_data = []

for file in json_files:
    with open(os.path.join(folder_path, file), 'r') as f:
        data = json.load(f)
        combined_data.extend(data)  # or use `.append(data)` for dictionary data

# Save the combined data to a new JSON file
with open('/content/drive/MyDrive/ai class data/image/combined_data.json', 'w') as f:
    json.dump(combined_data, f, indent=4)

# %% [markdown]
# To download images from a list of URLs provided in a CSV or JSON file and save them to a designated folder, you can follow this streamlined process:

# %% [markdown]
# **Step 1:** Import Libraries
#
# Start by importing the necessary libraries:

# %%
import pandas as pd
import requests
import os
from PIL import Image

# %% [markdown]
# **Step 2:** Read the CSV or json File
#
# Load the CSV file containing image URLs using Pandas. Replace "**your_file.json**" with the actual path to your CSV file and specify the column containing the image URLs (e.g., "image_url").

# %%
import json
#############################################################################
# Load the JSON file
json_file_path = "/content/drive/MyDrive/ai class data/image/combined_data.json"
#############################################################################
# Initialize an empty list to store the image URLs
image_urls = []

# Read and parse the JSON file
with open(json_file_path, "r") as json_file:
    data = json.load(json_file)

    # Assuming your JSON data is a list of dictionaries with an "image_url" field
    for item in data:
        if "image_url" in item:
            image_url = item["image_url"]
            image_urls.append(image_url)

# Now, image_urls contains the image URLs from the JSON data
# You can use this list as needed

# %%
image_urls
# Out:
# ['https://www.facebook.com/tr?id=350870482443432&ev=PageView&noscript=1',
#  'https://assets.adsttc.com/doodles/flat/logo-blue-full.svg',
#  'https://assets.adsttc.com/doodles/flat/logo-blue-full.svg',
#  'https://assets.adsttc.com/doodles/flat/logo-blue-full.svg',
#  'https://assets.adsttc.com/doodles/flat/logo-animation.gif',
#  'https://images.adsttc.com/media/images/65ae/e3f4/9936/3f1e/55ff/f330/newsletter/house-n0-use-studio_11.jpg?1705960502',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  'https://images.adsttc.com/media/images/65ae/e3f3/e32f/dc2f/927b/735c/newsletter/house-n0-use-studio_21.jpg?1705960462',
#  'https://images.adsttc.com/media/images/65ae/e3f2/e32f/dc56/56fe/0128/newsletter/house-n0-use-studio_1.jpg?1705960465',
#  'https://images.adsttc.com/media/images/65ae/e405/9936/3f2c/2119/5b40/newsletter/plans-3.jpg?1705960487',
#  'https://images.adsttc.com/media/images/65ae/e3f2/e32f/dc2f/927b/7359/newsletter/house-n0-use-studio_6.jpg?1705960465',
#  'https://images.adsttc.com/media/images/65ae/e3f4/e32f/dc56/56fe/012c/newsletter/house-n0-use-studio_2.jpg?1705960484',
#  'https://images.adsttc.com/media/images/65ae/e404/e32f/dc2f/927b/735e/newsletter/lights-2.jpg?1705960490',
#  'https://images.adsttc.com/media/images/65ae/e3ef/e32f/dc2f/927b/7357/medium_jpg/house-n0-use-studio_13.jpg?1705960453',
#  'https://images.adsttc.com/media/images/65ae/e3f3/e32f/dc2f/927b/735b/medium_jpg/house-n0-use-studio_18.jpg?1705960457',
#  'https://images.adsttc.com/media/images/65ae/e3f2/9936/3f2c/2119/5b3c/medium_jpg/house-n0-use-studio_4.jpg?1705960464',
#  'https://images.adsttc.com/media/images/65ae/e405/e32f/dc2f/927b/7360/newsletter/section-b-b-6.jpg?1705960484',
#  'https://images.adsttc.com/media/images/65ae/e3f3/e32f/dc56/56fe/012a/newsletter/house-n0-use-studio_8.jpg?1705960535',
#  'https://images.adsttc.com/media/images/65ae/e3f4/9936/3f1e/55ff/f330/medium_jpg/house-n0-use-studio_11.jpg?1705960502',
#  'https://images.adsttc.com/media/images/65ae/e3f3/e32f/dc2f/927b/735c/medium_jpg/house-n0-use-studio_21.jpg?1705960462',
#  'https://images.adsttc.com/media/images/65ae/e3ef/e32f/dc2f/927b/7357/medium_jpg/house-n0-use-studio_13.jpg?1705960453',
#  'https://images.adsttc.com/media/images/65ae/e3f4/e32f/dc56/56fe/012c/medium_jpg/house-n0-use-studio_2.jpg?1705960484',
#  'https://images.adsttc.com/media/images/65ae/e3f2/e32f/dc56/56fe/0128/medium_jpg/house-n0-use-studio_1.jpg?1705960465',
#  'https://images.adsttc.com/media/images/65ae/e3f3/9936/3f1e/55ff/f32e/medium_jpg/house-n0-use-studio_22.jpg?1705960502',
#  'https://images.adsttc.com/media/images/65ae/e3f3/e32f/dc2f/927b/735b/medium_jpg/house-n0-use-studio_18.jpg?1705960457',
#  'https://images.adsttc.com/media/images/65ae/e3f4/e32f/dc2f/927b/735d/medium_jpg/house-n0-use-studio_3.jpg?1705960505',
#  'https://images.adsttc.com/media/images/65ae/e3f2/9936/3f2c/2119/5b3c/medium_jpg/house-n0-use-studio_4.jpg?1705960464',
#  'https://images.adsttc.com/media/images/65ae/e3f1/e32f/dc2f/927b/7358/medium_jpg/house-n0-use-studio_20.jpg?1705960449',
#  'https://images.adsttc.com/media/images/65ae/e3f3/e32f/dc56/56fe/012a/medium_jpg/house-n0-use-studio_8.jpg?1705960535',
#  'https://images.adsttc.com/media/images/65ae/e3f3/e32f/dc56/56fe/012b/medium_jpg/house-n0-use-studio_10.jpg?1705960495',
#  'https://images.adsttc.com/media/images/65ae/e3f2/9936/3f1e/55ff/f32c/medium_jpg/house-n0-use-studio_9.jpg?1705960450',
#  'https://images.adsttc.com/media/images/65ae/e3f4/9936/3f2c/2119/5b3e/medium_jpg/house-n0-use-studio_12.jpg?1705960521',
#  'https://images.adsttc.com/media/images/65ae/e3f3/9936/3f1e/55ff/f32f/medium_jpg/house-n0-use-studio_14.jpg?1705960489',
#  'https://images.adsttc.com/media/images/65ae/e3f2/e32f/dc2f/927b/7359/medium_jpg/house-n0-use-studio_6.jpg?1705960465',
#  'https://images.adsttc.com/media/images/65ae/e3f3/9936/3f2c/2119/5b3d/medium_jpg/house-n0-use-studio_15.jpg?1705960469',
#  'https://images.adsttc.com/media/images/65ae/e3f3/e32f/dc2f/927b/
# 13    https://images.adsttc.com/media/images/659e/cb...
# 14    https://images.adsttc.com/media/images/659e/cb...
# 15    https://images.adsttc.com/media/images/659e/cb...
# 16    https://images.adsttc.com/media/images/659e/cb...
# 17    https://images.adsttc.com/media/images/659e/cb...
# 18    https://images.adsttc.com/media/images/659e/cb...
# 19    https://images.adsttc.com/media/images/659e/cb...
# 20    https://images.adsttc.com/media/images/659e/cb...
# 21    https://images.adsttc.com/media/images/659e/cb...
# 22    https://images.adsttc.com/media/images/659e/cb...
# 23    https://images.adsttc.com/media/images/659e/cb...
# 24    https://images.adsttc.com/media/images/659e/cb...
# 25    https://images.adsttc.com/media/images/659e/cb...
# 26    https://images.adsttc.com/media/images/659e/cb...
# 27    https://images.adsttc.com/media/images/659e/cb...
# 28    https://images.adsttc.com/media/images/659e/cb...
# 29    https://images.adsttc.com/media/images/659e/cb...
# 30    https://images.adsttc.com/media/images/659e/cb...
# 31    https://images.adsttc.com/media/images/659e/cb...
# 32    https://images.adsttc.com/media/images/659e/cb...
# 33    https://images.adsttc.com/media/images/659e/cb...
# 34    https://images.adsttc.com/media/images/659e/cb...
# 35    https://images.adsttc.com/media/images/659e/cb...
# 36    https://images.adsttc.com/media/images/659e/cb...
# 37    https://images.adsttc.com/media/images/659e/cb...
# 38    https://images.adsttc.com/media/images/659e/cb...
# 39    https://images.adsttc.com/media/images/659e/cb...
# 40    https://images.adsttc.com/media/images/659e/cb...
# 41    https://images.adsttc.com/media/images/659e/cb...
# 42    https://images.adsttc.com/media/images/659e/cb...
# 43    https://images.adsttc.com/media/images/659e/cb...
# 44    https://images.adsttc.com/media/images/659e/cb...
# 45    https://images.adsttc.com/media/images/659e/cb...
# 46    https://images.adsttc.com/media/images/659e/cb...
# 47    https://images.adsttc.com/media/images/659e/cb...
# 48    https://images.adsttc.com/media/images/659e/cb...
# 49    https://images.adsttc.com/media/images/659e/cb...
# 50    https://images.adsttc.com/media/images/659e/cb...
# Name: image_url, dtype: object

# %% [markdown]
# **Step 3:** Create a Folder to Save Images
#
# Create a folder to save the downloaded images if it doesn't already exist. You can specify the folder name as you like.

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
output_folder = "downloaded_images"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %% [markdown]
# **Step 4:** Download and Save Images
#
# Iterate through the image URLs, download each image, and save it to the folder you created in Step 3.

# %%
for i, url in enumerate(image_urls):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            image_content = response.content
            with open(os.path.join(output_folder, f"image_{i+1}.jpg"), "wb") as f:
                f.write(image_content)
            print(f"Image {i+1} downloaded and saved.")
        else:
            print(f"Failed to download image {i+1}. Status code: {response.status_code}")
    except Exception as e:
        print(f"Error downloading image {i+1}: {str(e)}")
# Out:
# Image 1 downloaded and saved.
# Image 2 downloaded and saved.
# Image 3 downloaded and saved.
# Image 4 downloaded and saved.
# Image 5 downloaded and saved.
# Image 6 downloaded and saved.
# Error downloading image 7: No connection adapters were found for '...'
# Error downloading image 8: No connection adapters were found for '...'
# Error downloading image 9: No connection adapters were found for '...'
# Error downloading image 10: No connection adapters were found for '...'
# Error downloading image 11: No connection adapters were found for '...'
# Image 12 downloaded and saved.
# Image 13 downloaded and saved.
# Image 14 downloaded and saved.
# Image 15 downloaded and saved.
# Image 16 downloaded and saved.
# Image 17 downloaded and saved.
# Image 18 downloaded and saved.
# Image 19 downloaded and saved.
# Image 20 downloaded and saved.
# Image 21 downloaded and saved.
# Image 22 downloaded and saved.
# Image 23 downloaded and saved.
# Image 24 downloaded and saved.
# Image 25 downloaded and saved.
# Image 26 downloaded and saved.
# Image 27 downloaded and saved.
# Image 28 downloaded and saved.
# Image 29 downloaded and saved.
# Image 30 downloaded and saved.
# Image 31 downloaded and saved.
# Image 32 downloaded and saved.
# Image 33 downloaded and saved.
# Image 34 downloaded and saved.
# Image 35 downloaded and saved.
# Image 36 downloaded and saved.
# Image 37 downloaded and saved.
# Image 38 downloaded and saved.
# Image 39 downloaded and saved.
# Image 40 downloaded and saved.
# Image 41 downloaded and saved.
# Image 42 downloaded and saved.
# Image 43 downloaded and saved.
# Image 44 downloaded and saved.
# Image 45 downloaded and saved.
# Image 46 downloaded and saved.
# Image 47 downloaded and saved.
# Image 48 downloaded and saved.
# Image 49 downloaded and saved.
# Image 50 downloaded and saved.
# Image 51 downloaded and saved.

# %% [markdown]
# This code will download the images one by one from the URLs in your CSV file and save them with names like "image_1.jpg," "image_2.jpg," and so on in the specified output folder.

# %% [markdown]
# **Step 5:** Optional - Display Images
#
# If you want to display the downloaded images, you can use the PIL library:

# %%
from PIL import Image
import matplotlib.pyplot as plt
#####################################################################################
# Specify the file path
image_path = '/content/drive/MyDrive/Colab Notebooks/downloaded_images/image_28.jpg'
#####################################################################################
# Check if the file exists
if os.path.isfile(image_path):
    # Open and display the image using Matplotlib
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()
else:
    print(f"Image file not found at: {image_path}")

# %% [markdown]
# # **Image color**
# This part will guide you through various image color processing techniques using Python. We will use the `cv2` library for image manipulation and `matplotlib` for displaying the images.
#
# **Step 1:** Import Libraries and Load the Image
#
# Start by importing the necessary libraries and loading the downloaded image:

# %%
import cv2
import matplotlib.pyplot as plt

# Load the downloaded image
image_path = '/content/drive/MyDrive/Colab Notebooks/downloaded_images/image_28.jpg'
image = cv2.imread(image_path)

# %% [markdown]
# **Step 2:** Display the Original Image
#
# Display the original image using Matplotlib:

# %%
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB
plt.title('Original Image')
plt.axis('off')
plt.show()

# %% [markdown]
# Now, you can perform various image manipulation tasks on this image.
#
# **Step 3:** Change Color
#
# Change the color of the image by applying a color transformation. For example, let's convert the image to grayscale:

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display the grayscale image
plt.figure(figsize=(6, 6))
plt.imshow(gray_image, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %% [markdown]
# **Step 4:** Split Channels
#
# You can split the image into its color channels (Red, Green, and Blue) and display each channel separately. Here's an example with the Blue channel:

# %%
# Split the image into color channels
b, g, r = cv2.split(image)

# Create a 1x3 grid of subplots for displaying the channels
plt.figure(figsize=(18, 6))

# Display the Blue channel in the first subplot
plt.subplot(131)
plt.imshow(b, cmap='Blues')
plt.title('Blue Channel')
plt.axis('off')

# Display the Green channel in the second subplot
plt.subplot(132)
plt.imshow(g, cmap='Greens')
plt.title('Green Channel')
plt.axis('off')

# Display the Red channel in the third subplot
plt.subplot(133)
plt.imshow(r, cmap='Reds')
plt.title('Red Channel')
plt.axis('off')

plt.show()

# %% [markdown]
# **Step 5: Resize Image**
#
# Resize the image to a specific size:

# %%
image.shape
# Out:
# (396, 528, 3)

# %%
# Resize the image to a new width and height
new_width = 200
new_height = 200
resized_image = cv2.resize(image, (new_width, new_height))

# Display the resized image
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.title('Resized Image')
plt.axis('off')
plt.show()

# %%
resized_image.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# **Step 6:** Apply Filters
#
# You can apply various filters to the image, such as blurring or sharpening. Here's an example of blurring the image using Gaussian blur:

# %%
# Apply Gaussian blur to the original image
blurred_image = cv2.GaussianBlur(image, (11, 11), 0)

# Create a Matplotlib figure to display the blurred image
plt.figure(figsize=(6, 6))

# Convert the color format from BGR to RGB for proper display
blurred_rgb_image = cv2.cvtColor(blurred_image, cv2.COLOR_BGR2RGB)

# Display the blurred RGB image
plt.imshow(blurred_rgb_image)

# Set a title for the displayed image
plt.title('Blurred Image')

# Turn off axis labels and ticks for a cleaner display
plt.axis('off')

# Show the image in the Matplotlib plot
plt.show()

# %% [markdown]
# # **Edge Detection**
#
# Edge detection is a technique used in image processing and computer vision to identify the boundaries or edges within an image. These edges represent significant changes in intensity or color and often correspond to the boundaries of objects within the image. Detecting these edges is crucial for understanding the structure of objects and scenes in the image.
#
# To perform edge detection on an image in Python, you can use the popular library OpenCV. Here are the steps to perform edge detection on the image you downloaded:

# %% [markdown]
# **Step 1:** Import Libraries
#
# Start by importing the necessary libraries:

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Make sure you have OpenCV installed in your Colab environment. You can install it using `!pip install opencv-python` if it's not already installed.

# %% [markdown]
# **Step 2:** Load the Image
#
# Load the downloaded image using OpenCV:

# %%
image_path = '/content/drive/MyDrive/Colab Notebooks/downloaded_images/image_28.jpg'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %% [markdown]
# The `cv2.IMREAD_GRAYSCALE `flag loads the image in grayscale mode, which simplifies edge detection.

# %% [markdown]
# **Step 3:** Perform Edge Detection
#
# The Canny edge detection algorithm is a multi-step process. It is widely used in computer vision and image processing due to its ability to detect a wide range of edges in images. The algorithm is designed to be robust to noise and to find the most significant edges in an image.
#
# Perform edge detection on the loaded image using the Canny edge detection algorithm:

# %%
edges = cv2.Canny(image, threshold1=30, threshold2=100)

# %% [markdown]
# You can adjust the threshold1 and threshold2 parameters to control the sensitivity of edge detection. These values determine the lower and upper thresholds for edge detection.

# %% [markdown]
# **Step 4:** Display the Original Image and Edge Image
#
# Display both the original image and the edge-detected image using Matplotlib:

# %%
# Display the original image
plt.figure(figsize=(10, 10))
plt.subplot(121)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

# Display the edge-detected image
plt.subplot(122)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detection')
plt.axis('off')

plt.show()

# %% [markdown]
# # **Save Feature extracted from edge detection in csv file**

# %% [markdown]
# This part will guide you through extracting features from edge-detected images and saving these features in a CSV file using Python.

# %%
import cv2
import csv
import numpy as np

def extract_features(image_path):
    # Check if the image file exists
    if not os.path.exists(image_path):
        return None, "File not found"

    # Read the image
    image = cv2.imread(image_path)

    # Check if the image was loaded successfully
    if image is None:
        return None, "Image not loaded"
    # Convert to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # Resize image if necessary
    resized_image = cv2.resize(gray_image, (width, height))  # Define width and height
    # Perform edge detection
    edges = cv2.Canny(resized_image, threshold1=30, threshold2=100)
    # Flatten the edge image to create a feature vector
    feature_vector = edges.flatten()
    return feature_vector


width=28
height=28
# List of image file paths
image_paths = ['/content/drive/MyDrive/Colab Notebooks/downloaded_images/image_122.jpg', '/content/drive/MyDrive/Colab Notebooks/downloaded_images/image_123.jpg', '/content/drive/MyDrive/Colab Notebooks/downloaded_images/image_125.jpg']
# List to hold all feature vectors
feature_vectors = []

# Open the CSV file for writing
with open('feature_vectors.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    # Write the header
    writer.writerow(['image_name', 'features'])

    # Extract features for each image and write to the CSV file
    for path in image_paths:
        features = extract_features(path)
        # Write the image name and feature string to the CSV
        writer.writerow([path, features])

# %% [markdown]
# You can do some preprocessing steps for all images and save in csv file. because it good to do not repeat every time.

# %%
import os
import numpy as np
from PIL import Image
import pandas as pd

def load_and_preprocess_image(image_path, size=(64, 64)):
    try:
        # Load the image
        img = Image.open(image_path)
        # Resize and convert to grayscale
        img = img.resize(size).convert('L')
        # Normalize and flatten
        image_data = np.array(img).flatten() / 255.0
        # Get file name
        file_name = os.path.basename(image_path)
        return file_name, image_data
    except IOError:
        print(f"Cannot process image: {image_path}")
        return None

def save_to_csv(data, filename):
    # Remove None values
    data = [d for d in data if d is not None]
    # Create DataFrame
    df = pd.DataFrame(data, columns=['FileName', 'ImageData'])
    # Save to CSV
    df.to_csv(filename, index=False)

# Directory where your images are stored
image_dir = '/content/drive/MyDrive/Colab Notebooks/downloaded_images'
image_paths = [os.path.join(image_dir, file) for file in os.listdir(image_dir) if file.endswith('.jpg')]

# Process each image and store in a list
processed_images = [load_and_preprocess_image(path) for path in image_paths]

# Save to CSV
save_to_csv(processed_images, 'preprocessed_images.csv')
# Out:
# Cannot process image: /content/drive/MyDrive/Colab Notebooks/downloaded_images/image_1.jpg
# Cannot process image: /content/drive/MyDrive/Colab Notebooks/downloaded_images/image_2.jpg
# Cannot process image: /content/drive/MyDrive/Colab Notebooks/downloaded_images/image_3.jpg
# Cannot process image: /content/drive/MyDrive/Colab Notebooks/downloaded_images/image_4.jpg
